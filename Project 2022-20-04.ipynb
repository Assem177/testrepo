# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Assem Nurseitova__
#
# Data Scientist

# %% [markdown]
# _I am interested in data science because I see my future in this sphere_

# %% [markdown]
# ### The following code shows the summ of two numbers 44 and 55

# %%
print (44+55)
# Out:
# 99

# %% [markdown]
# [logo]: https://upload.wikimedia.org/wikipedia/commons/f/fa/Apple_logo_black.svg

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=-tJYN-eG1zk"> If you like Queen</a>
#
# ![alt text](https://www.tutorialspoint.com/jupyter/images/jupyter_logo.jpg "Jupyter")
#
#
# 1. First
# 2. Second
#   * Third
#   * Fourth
